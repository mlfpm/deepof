# %%
import os
os.chdir("../../..")
import deepof.data

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # DeepOF supervised pipeline: detecting pre-defined behaviors

# %% [markdown]
# ##### Tutorial index:
#
#     * Brief introduction to supervised analysis, including the figure with all tracked behaviors.
#     * Load the previous project.
#     * Run the supervised annotation pipeline.
#     * Visualize global embeddings using the retrieved traits.
#     * Visualize animated unsupervised embeddings, coloured by specific traits.
#     * Explore trait enrichment across conditions.
#     * Generate Gantt plots with all traits.
#     * Export video snippets.

# %% [markdown]
# ### Supervised annotation in DeepOF - search for pre-established patterns

# %% [markdown]
# ### Load a previously initiated project

# %%
import pickle

# # FC data
# my_deepof_project = deepof.data.load_project("./deepof_FC_project_files/")

# with open("./deepof_FC_project_files/Coordinates/FC_dataset_experimental_conditions.pkl", "rb") as handle:
#     exp_conditions = pickle.load(handle)
# my_deepof_project._exp_conditions = exp_conditions

# SI data
my_deepof_project = deepof.data.load_project("../../Desktop/deepOF_datasets/Tagged_videos/Data_for_deepof_SI/deepof_SI_project/")
with open("deepof_SI_exp_conds.pkl", "rb") as handle:
    exp_conds = pickle.load(handle)
my_deepof_project._exp_conditions = exp_conds

# Update project path to a local path
my_deepof_project._project_path = "../../Desktop/deepOF_datasets/Tagged_videos/Data_for_deepof_SI/"
my_deepof_project._project_name = "deepof_SI_project"
my_deepof_project._trained_model_path = "./deepof/trained_models/"

# %% [markdown]
# ### Run the supervised annotation pipeline.

# %%
for key, val in supervised_annotation.items():
    val.to_csv("../../Desktop/" + key + "_supervised_labels.csv")

# %%
supervised_annotation = my_deepof_project.supervised_annotation(
    video_output=['20191203_Day1_SI_JB08_Test_14'], frame_limit=150, debug=True,
)
# Out:
#   0%|                                                                                                                                                                                    | 0/53 [00:00<?, ?it/s]
#
#   2%|███▏                                                                                                                                                                        | 1/53 [00:03<03:13,  3.73s/it]
#
#   4%|██████▍                                                                                                                                                                     | 2/53 [00:07<02:59,  3.53s/it]
#
#   6%|█████████▋                                                                                                                                                                  | 3/53 [00:10<03:01,  3.63s/it]
#
#   8%|████████████▉                                                                                                                                                               | 4/53 [00:15<03:16,  4.01s/it]
#
#   9%|████████████████▏                                                                                                                                                           | 5/53 [00:18<02:57,  3.70s/it]
#
#  11%|███████████████████▍                                                                                                                                                        | 6/53 [00:21<02:45,  3.51s/it]
#
#  13%|██████████████████████▋                                                                                                                                                     | 7/53 [00:25<02:40,  3.49s/it]
#
#  15%|█████████████████████████▉                                                                                                                                                  | 8/53 [00:29<02:44,  3.65s/it]
#
#  17%|█████████████████████████████▏                                                                                                                                              | 9/53 [00:32<02:36,  3.55s/it]
#
#  19%|████████████████████████████████▎                                                                                                                                          | 10/53 [00:36<02:44,  3.82s/it]
#
#  21%|███████████████████████████████████▍                                                                                                                                       | 11/53 [00:40<02:40,  3.82s/it]
#
#  23%|██████████████████████████████████████▋                                                                                                                                    | 12/53 [00:43<02:26,  3.58s/it]
#
#  25%|█████████████████████████████████████████▉                                                                                                                                 | 13/53 [00:47<02:18,  3.46s/it]
#
#  26%|█████████████████████████████████████████████▏                                                                                                                             | 14/53 [00:50<02:18,  3.55s/it]
#
#  28%|████████████████████████████████████████████████▍                                                                                                                          | 15/53 [00:54<02:13,  3.52s/it]
#
#  30%|███████████████████████████████████████████████████▌                                                                                                                       | 16/53 [00:57<02:12,  3.59s/it]
#
#  32%|██████████████████████████████████████████████████████▊                                                                                                                    | 17/53 [01:01<02:06,  3.52s/it]
#
#  34%|██████████████████████████████████████████████████████████                                                                                                                 | 18/53 [01:04<02:00,  3.45s/it]
#
#  36%|█████████████████████████████████████████████████████████████▎                                                                                                             | 19/53 [01:07<01:46,  3.14s/it]
#
#  38%|████████████████████████████████████████████████████████████████▌                                                                                                          | 20/53 [01:10<01:48,  3.29s/it]
#
#  40%|███████████████████████████████████████████████████████████████████▊                                                                                                       | 21/53 [01:13<01:44,  3.26s/it]
#
#  42%|██████████████████████████████████████████████████████████████████████▉                                                                                                    | 22/53 [01:18<01:51,  3.60s/it]
#
#   0%|                                                                                                                                                                                     | 0/1 [08:49<?, ?it/s]
#
#
#  45%|█████████████████████████████████████████████████████████████████████████████▍                                                                                             | 24/53 [01:24<01:36,  3.34s/it]
#
#  47%|████████████████████████████████████████████████████████████████████████████████▋                                                                                          | 25/53 [01:28<01:36,  3.44s/it]
#
#  49%|███████████████████████████████████████████████████████████████████████████████████▉                                                                                       | 26/53 [01:31<01:31,  3.39s/it]
#
#  51%|███████████████████████████████████████████████████████████████████████████████████████                                                                                    | 27/53 [01:34<01:28,  3.41s/it]
#
#  53%|██████████████████████████████████████████████████████████████████████████████████████████▎                                                                                | 28/53 [01:37<01:23,  3.33s/it]
#
#  55%|█████████████████████████████████████████████████████████████████████████████████████████████▌                                                                             | 29/53 [01:41<01:22,  3.43s/it]
#
#  57%|████████████████████████████████████████████████████████████████████████████████████████████████▊                                                                          | 30/53 [01:44<01:16,  3.33s/it]
#
#  58%|████████████████████████████████████████████████████████████████████████████████████████████████████                                                                       | 31/53 [01:48<01:19,  3.63s/it]
#
#  60%|███████████████████████████████████████████████████████████████████████████████████████████████████████▏                                                                   | 32/53 [01:52<01:16,  3.66s/it]
#
#  62%|██████████████████████████████████████████████████████████████████████████████████████████████████████████▍                                                                | 33/53 [01:55<01:10,  3.54s/it]
#
#  64%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████▋                                                             | 34/53 [01:59<01:07,  3.54s/it]
#
#  66%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉                                                          | 35/53 [02:03<01:05,  3.64s/it]
#
#  68%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                                                      | 36/53 [02:06<01:00,  3.59s/it]
#  70%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                                                   | 37/53 [02:10<00:57,  3.62s/it]
#
#  72%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                                                | 38/53 [02:14<00:54,  3.64s/it]
#
#  74%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊                                             | 39/53 [02:18<00:54,  3.87s/it]
#
#  75%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                                          | 40/53 [02:21<00:46,  3.60s/it]
#
#  77%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎                                      | 41/53 [02:24<00:41,  3.45s/it]
#
#  79%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                                   | 42/53 [02:28<00:38,  3.51s/it]
#
#  81%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋                                | 43/53 [02:31<00:34,  3.46s/it]
#
#  83%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉                             | 44/53 [02:35<00:31,  3.47s/it]
#
#  85%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                         | 45/53 [02:38<00:26,  3.34s/it]
#
#  87%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                      | 46/53 [02:42<00:24,  3.47s/it]
#
#  89%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋                   | 47/53 [02:46<00:22,  3.80s/it]
#
#  91%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊                | 48/53 [02:50<00:18,  3.80s/it]
#
#  92%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████             | 49/53 [02:53<00:14,  3.69s/it]
#
#  94%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎         | 50/53 [02:57<00:11,  3.67s/it]
#
#  96%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌      | 51/53 [03:00<00:07,  3.53s/it]
#
#  98%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊   | 52/53 [03:03<00:03,  3.39s/it]
#
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 53/53 [03:06<00:00,  3.52s/it]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.62s/it]

# %%
my_deepof_project._project_name
# Out:
# 'deepof_SI_project'

# %% [markdown]
# ### Explore trait enrichment across conditions.

# %%
tt = pd.read_csv(
    "../../Desktop/deepOF_datasets/Tagged_videos/Data_for_deepof_OF/deepof_OF_classifiers/project_folder/csv/targets_inserted/20191203_Day1_OF_JB08_Test_12.csv", index_col=0
)

# %%
tt.sum()

# %%
tt

# %%
tt.to_csv(
    "../../Desktop/deepOF_datasets/Tagged_videos/Data_for_deepof_OF/deepof_OF_classifiers/project_folder/csv/targets_inserted/20191203_Day1_OF_JB08_Test_12.csv",
)

# %% [markdown]
# ### Generate Gantt plots with all traits.

# %% [markdown]
# ### Exporting video snippets
