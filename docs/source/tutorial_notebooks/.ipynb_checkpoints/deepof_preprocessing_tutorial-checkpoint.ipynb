# %%
import os
os.chdir("../../..")
import deepof.data

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Formatting your data: feature extraction from motion tracking output

# %%
# Create and run a project. Explore different processing parameters (smoothing, imputation)

# %%
my_deepof_project = deepof.data.Project(
                path=os.path.join("../../Desktop/deepOF_CSDS_tutorial_dataset/"),
                arena="circular-autodetect",
                animal_ids=["B", "W"],
                video_format=".mp4",
                exclude_bodyparts=["Tail_1", "Tail_2", "Tail_tip"],
                video_scale=380,
                enable_iterative_imputation=False,
                exp_conditions={
                    '20191204_Day2_SI_JB08_Test_56': 'Stressed',
                    '20191204_Day2_SI_JB08_Test_61': 'Stressed',
                    '20191204_Day2_SI_JB08_Test_62': 'Stressed',
                    '20191204_Day2_SI_JB08_Test_54': 'Nonstressed',
                    '20191204_Day2_SI_JB08_Test_63': 'Nonstressed',
                    '20191204_Day2_SI_JB08_Test_64': 'Nonstressed'
                }
)

# %%
my_deepof_project = my_deepof_project.run()
# Out:
# Loading trajectories...
# Smoothing trajectories...
# Interpolating outliers...
# Detecting arena...
# Computing distances...
# Computing angles...
# Computing areas...
# Done!

# %%
my_deepof_project.get_areas()['20191204_Day2_SI_JB08_Test_54']
# Out:
#        B_head_area  B_torso_area  B_back_area  B_full_area  W_head_area  \
# 0       287.018462    467.472460   513.431000  1697.086099   588.316685
# 1       298.006089    461.593907   511.611552  1664.187297   532.941463
# 2       283.907493    436.994147   491.022208  1571.659017   615.224965
# 3       336.017364    459.434553   495.609970  1674.157290   664.955274
# 4       338.565821    456.785954   510.514167  1706.762126   589.501549
# ...            ...           ...          ...          ...          ...
# 14994   364.598702    512.092068   562.957165  1882.932433   516.368794
# 14995   342.771541    514.231920   543.299019  1832.083470   517.334943
# 14996   388.332158    529.127829   558.340318  1889.399535   516.875687
# 14997   388.332158    529.127829   558.340318  1889.399535   516.875687
# 14998   388.332158    529.127829   558.340318  1889.399535   516.875687
#
#        W_torso_area  W_back_area  W_full_area
# 0        575.287843   557.837678  2402.446220
# ...

# %%
# Save your project to avoid laborious repetitions

# %%
# my_deepof_project.save("../../Desktop/deepOF_CSDS_tutorial_dataset/deepof_tutorial_saved_coordinates")

# %%
# Load a previously saved project
my_deepof_project = deepof.data.load("../../Desktop/deepOF_CSDS_tutorial_dataset/deepof_tutorial_saved_coordinates_1670870158.pkl")

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import deepof.visuals
from matplotlib.patches import Ellipse

sns.set_context("talk")

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

deepof.visuals.plot_heatmaps(
    my_deepof_project, 
    ["B_Nose"],
    center="arena", 
    exp_condition="Nonstressed",
    ax=ax1,
    show=False,
    display_arena=True,
    experiment_id="average",
)

deepof.visuals.plot_heatmaps(
    my_deepof_project, 
    ["B_Nose"],
    center="arena", 
    exp_condition="Stressed",
    ax=ax2,
    show=False,
    display_arena=True,
    experiment_id="average",
)

plt.tight_layout()
plt.show()

# %%
import networkx as nx
from deepof.utils import connect_mouse_topview

G = connect_mouse_topview(animal_ids=["B", "W"], exclude_bodyparts=["Tail_1", "Tail_2", "Tail_tip"])
nx.draw(G, 
        with_labels=True, 
        pos=nx.spring_layout(G), 
        node_color=["red" if i.startswith("B") else "blue" for i in G.nodes()])

# %%
# Create a preprocessed version of the dataset we're after

def create_graph_dataset(animal_ids):

    # Get all required features in a single TabDict

    coords = my_deepof_project.get_coords(=animal_ids, center="Center", align="Spine_1")
    speeds = my_deepof_project.get_coords(speed=1)
    dists = my_deepof_project.get_distances()
    
    
    
create_graph_dataset("B")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [490], line 13
#       8     speeds = my_deepof_project.get_coords(speed=1)
#       9     dists = my_deepof_project.get_distances()
# ---> 13 create_graph_dataset("B")
#
# Cell In [490], line 7, in create_graph_dataset(animal_ids)
#       3 def create_graph_dataset(animal_ids):
#       4
#       5     # Get all required features in a single TabDict
# ----> 7     coords = my_deepof_project.get_coords(animal_ids=animal_ids, center="Center", align="Spine_1")
#       8     speeds = my_deepof_project.get_coords(speed=1)
#       9     dists = my_deepof_project.get_distances()
#
# TypeError: get_coords() got an unexpected keyword argument 'animal_ids'

# %%
import numpy as np

# Build an example fully annotated single animal graph

# Get adjacency matrix
G = connect_mouse_topview(animal_ids=["B"], exclude_bodyparts=["Tail_1", "Tail_2", "Tail_tip"])
a = nx.adjacency_matrix(G).astype(float)

# Get node features -> X,Y,speed
x = my_deepof_project.get_coords(center="Center", align="Spine_1", selected_id="B")['20191204_Day2_SI_JB08_Test_54'][list(G.nodes)]
x = x.values.reshape(x.shape[0], -1, 2)
s = my_deepof_project.get_coords(speed=1, selected_id="B")['20191204_Day2_SI_JB08_Test_54'][list(G.nodes)]
s = s.values.reshape(s.shape[0], -1, 1)
x = np.concatenate([x, s], axis=2)

# Get edge features -> distances
e = my_deepof_project.get_distances(selected_id="B")['20191204_Day2_SI_JB08_Test_54'][[tuple(sorted(e)) for e in list(G.edges)]]
e = np.expand_dims(e.values, axis=-1)

# Transform edge features into a weighted adjacency matrix
a = np.repeat(np.expand_dims(a.todense(), axis=0), e.shape[0], axis=0)
a[np.where(a)] =  np.concatenate([e, e[:,::-1]], axis=1).flatten()
# Out:
# /var/folders/wf/msmt6cvx5xl9t0p2qjd1tn65jtl6l8/T/ipykernel_33864/187680223.py:7: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   a = nx.adjacency_matrix(G).astype(float)

# %%
# Build an example fully annotated multi animal graph

# Get adjacency matrix
Gm = connect_mouse_topview(animal_ids=["B", "W"], exclude_bodyparts=["Tail_1", "Tail_2", "Tail_tip"])
am = nx.adjacency_matrix(Gm)

# Get node features -> X,Y,speed
xm = my_deepof_project.get_coords(speed=1)['20191204_Day2_SI_JB08_Test_54'][list(G.nodes)]
xm = xm.values.reshape(xm.shape[0], -1, 1)

# Get edge features -> distances
em = my_deepof_project.get_distances()['20191204_Day2_SI_JB08_Test_54'][[tuple(sorted(e)) for e in list(Gm.edges)]]
em = np.expand_dims(em.values, axis=-1)

# Transform edge features into a weighted adjacency matrix
am = np.repeat(np.expand_dims(am.todense(), axis=0), em.shape[0], axis=0)
am[np.where(am)] =  np.concatenate([em, em[:,::-1]], axis=1).flatten()
# Out:
# /var/folders/wf/msmt6cvx5xl9t0p2qjd1tn65jtl6l8/T/ipykernel_33864/1342484250.py:5: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   am = nx.adjacency_matrix(Gm)

# %%
from spektral.layers import GATConv, CensNetConv
a.shape
# Out:
# (14999, 11, 11)

# %%
t = np.random.normal(0, 1, [100, 25, 33])
tt = tt.reshape([-1] + [11, 3])

a = np.random.normal(0, 1, [100, 25, 11, 11])
aa = a.reshape([-1] + [11, 11])

g = GATConv(channels=10, attn_heads=10)([tt, aa])

g.numpy().reshape([100, 25, 11 * 10 * 10]).shape
# Out:
# (100, 25, 1100)

# %%
t.shape[1:]
# Out:
# (25, 33)

# %%
from deepof.models import get_recurrent_encoder, get_TCN_encoder, get_transformer_encoder
from deepof.models import get_recurrent_decoder, get_TCN_decoder, get_transformer_decoder

# %%
t.shape[1:]
# Out:
# (25, 33)

# %%
# Build simple recurrent AE

encoder = get_recurrent_encoder(t.shape[1:], a.shape[1:], 8)
decoder = get_recurrent_decoder(t.shape[1:], 8)

# %%
decoder([encoder([t, a]), t])
# Out:
# <tfp.distributions._TensorCoercible 'tensor_coercible' batch_shape=[100, 25] event_shape=[33] dtype=float32>

# %%
from deepof.models import VQVAE, VaDE, Contrastive
from deepof.models import get_vqvae, get_vade

# %%
vqvae = VQVAE(t.shape, a.shape)

# %%
vqvae.compile()
vqvae.fit([t, a, t], epochs=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [472], line 2
#       1 vqvae.compile()
# ----> 2 vqvae.fit([t, a, t], epochs=1)
#
# File ~/Library/Caches/pypoetry/virtualenvs/deepof-qxwF8hwh-py3.9/lib/python3.9/site-packages/keras/utils/traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67   raise e.with_traceback(filtered_tb) from None
#      68 finally:
#      69   del filtered_tb
#
# File /var/folders/wf/msmt6cvx5xl9t0p2qjd1tn65jtl6l8/T/__autograph_generated_file9edpwkwp.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__train_function(iterator)
#      13 try:
#      14     do_return = True
# ...

# %%
get_TCN_encoder(t.shape[1:], a.shape[1:], 8).summary()
# Out:
# Model: "TCN_encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_218 (InputLayer)         [(None, 25, 33)]     0           []
#
#  input_219 (InputLayer)         [(None, 25, 11, 11)  0           []
#                                 ]
#
#  tf.reshape_287 (TFOpLambda)    (None, 11, 3)        0           ['input_218[0][0]']
#
#  tf.reshape_288 (TFOpLambda)    (None, 11, 11)       0           ['input_219[0][0]']
#
#  gat_conv_130 (GATConv)         (None, 11, 128)      768         ['tf.reshape_287[0][0]',
#                                                                   'tf.reshape_288[0][0]']
#
#  tf.reshape_289 (TFOpLambda)    (None, 25, 1408)     0           ['gat_conv_130[0][0]']
#
#  tcn_28 (TCN)                   (None, 32)           289312      ['tf.reshape_289[0][0]']
#
# ...

# %%
get_transformer_encoder(t.shape[1:], a.shape[1:], 8).summary()
# Out:
# Model: "transformer_encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_212 (InputLayer)         [(None, 25, 33)]     0           []
#
#  input_213 (InputLayer)         [(None, 25, 11, 11)  0           []
#                                 ]
#
#  tf.reshape_277 (TFOpLambda)    (None, 11, 3)        0           ['input_212[0][0]']
#
#  tf.reshape_278 (TFOpLambda)    (None, 11, 11)       0           ['input_213[0][0]']
#
#  gat_conv_127 (GATConv)         (None, 11, 128)      768         ['tf.reshape_277[0][0]',
#                                                                   'tf.reshape_278[0][0]']
#
#  tf.reshape_279 (TFOpLambda)    (None, 25, 1408)     0           ['gat_conv_127[0][0]']
#
#  transformer_encoder_27 (Transf  (None, 25, 33)      1222073     ['tf.reshape_279[0][0]']
#  ormerEncoder)
#
# ...

# %%
# Do cluster assignments differ significantly across animals? Can we detect the animal from the assignments' histogram?
# Leave for later, when implementing the cluster enrichment and viz functions

# %%
from IPython import display

video = deepof.visuals.animate_skeleton(
    my_deepof_project,
    #embedding=emb,
    #cluster_assignments=clust_ass,
    #animal_id="W",
    experiment_id="20191204_Day2_SI_JB08_Test_54",
    frame_limit=250,
    # selected_cluster=0,
    dpi=60,
    # center="Center",
    # align="Spine_1",
    #embedding=[emb_B, emb_W],
    save="SAB_multi_animal_example.mp4",
)

html = display.HTML(video)
display.display(html)
plt.close()

# %%
# Single animal display

# %%
from sklearn.decomposition import PCA

emb = PCA(n_components=3).fit_transform(my_deepof_project.get_coords().filter_id("B")['20191204_Day2_SI_JB08_Test_56'])

# %%
from IPython import display

video = deepof.visuals.animate_skeleton(
    my_deepof_project,
    animal_id="B",
    embedding=emb,
    experiment_id="20191204_Day2_SI_JB08_Test_56",
    frame_limit=750,
    dpi=60,
)

html = display.HTML(video)
display.display(html)
plt.close()

# %%
emb = PCA(n_components=3).fit_transform(my_deepof_project.get_coords(center="Center", align="Spine_1").filter_id("B")['20191204_Day2_SI_JB08_Test_56'])

# %%
from IPython import display

video = deepof.visuals.animate_skeleton(
    my_deepof_project,
    center="Center",
    align="Spine_1",
    animal_id="B",
    embedding=emb,
    experiment_id="20191204_Day2_SI_JB08_Test_56",
    frame_limit=750,
    dpi=60,
)

html = display.HTML(video)
display.display(html)
plt.close()

# %%
# Get and plot coordinates, distances, angles, and areas. Try and visualizing different centering and rotations

# %%
my_deepof_project.get_coords(polar=True)['20191204_Day2_SI_JB08_Test_54']

# %%
my_deepof_project.get_distances()['20191204_Day2_SI_JB08_Test_54']

# %%
my_deepof_project.get_angles()['20191204_Day2_SI_JB08_Test_54']

# %%
my_deepof_project.get_areas()

# %%
my_deepof_project.get_areas()['20191204_Day2_SI_JB08_Test_54']

# %%
# Show how to merge different feature objects

my_deepof_project.get_coords().pca()
