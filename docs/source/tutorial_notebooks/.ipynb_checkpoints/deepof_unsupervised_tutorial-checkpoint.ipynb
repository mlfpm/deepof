# %%
import os
os.chdir("../../..")
import deepof.data

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # DeepOF unsupervised pipeline: exploring the behavioral space

# %% [markdown]
# ##### Tutorial index:
#
# * Brief introduction to unsupervised analysis.
# * Load your previous project.
# * Running an unsupervised analysis with default parameters.
# * Understanding the different available models.
# * Cluster number selection.
# * Temporal and global embeddings.
# * Global separation dynamics.
# * Exploring cluster enrichment across conditions.
# * Exploring cluster dynamics across conditions.
# * Interpreting clusters using SHAP.
# * Exporting cluster video snippets.

# %% [markdown]
# ### Brief introduction to unsupervised analysis

# %% [markdown]
# ### Load your previous project

# %%
my_deepof_project = deepof.data.load_project("../../Desktop/deepOF_CSDS_tutorial_dataset/deepof_tutorial/")

# %%
# THIS SHOULD BE THE LAST SECTION OF THE FIRST TUTORIAL!

# Check scales across animals. Can we detect to which animal a given time series belongs to?
# Once happy with a solution, check that all animals show comparable cluster interpretations.

# Add preprocessing options to include multiple animals, concatenated and together in a graph

tt = my_deepof_project.get_coords(center="Center", align="Spine_1")
# ss = my_deepof_project.get_coords(speed=1)

# tt = cc.merge(ss)

tt = tt.preprocess(
    window_size=25,
    window_step=1,
    test_videos=1,
    scale="standard",
    handle_ids="split", # "concat" uses bps from != animals as features, "split"
)

tt = (tt[0][:25000], tt[1][:25000], tt[2][:25000], tt[3][:25000])

# %%
# SAME HERE: Last section of the last tutorial should explore tensor and graph preprocessing

from deepof.utils import connect_mouse_topview
import networkx as nx

pp, G, to_preprocess = my_deepof_project.get_graph_dataset(
    animal_id="B",
    center="Center",
    align="Spine_1",
    preprocess="standard",
    scale=False
)

adj = nx.adjacency_matrix(G).todense()
pp = (pp[0][:25000], pp[1][:25000], pp[2][:25000], pp[3][:25000], pp[4][:25000], pp[5][:25000])
# Out:
# /var/folders/wf/msmt6cvx5xl9t0p2qjd1tn65jtl6l8/T/ipykernel_27114/3271398293.py:14: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   adj = nx.adjacency_matrix(G).todense()

# %% [markdown]
# ### Running an unsupervised analysis with default parameters

# %%
from tensorflow.keras.layers import GRU, TimeDistributed

# Shape should be Batch x Nodes x Time x Features
TimeDistributed(GRU(10, return_sequences=False))(np.random.uniform(0, 1, [100, 11, 25, 2])).numpy().shape

# Output is Batch X Nodes X hidden features
# Out:
# (100, 11, 10)

# %%
pp[1].shape
# Out:
# (25000, 25, 11)

# %%
tt[0].shape[1:]
# Out:
# (25, 22)

# %%
from deepof.models import get_recurrent_encoder

enc = get_recurrent_encoder(tt[0].shape[1:], tt[1].shape[1:], nx.adjacency_matrix(G).todense(), 4, use_gnn=False)
# enc(tt[0])
# Out:
# /var/folders/wf/msmt6cvx5xl9t0p2qjd1tn65jtl6l8/T/ipykernel_27114/3636541995.py:3: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   enc = get_recurrent_encoder(tt[0].shape[1:], tt[1].shape[1:], nx.adjacency_matrix(G).todense(), 4, use_gnn=False)

# %%
# %%time
cons = my_deepof_project.deep_unsupervised_embedding(
    pp,
    adjacency_matrix=adj,
    embedding_model="VaDE",
    epochs=15,
    encoder_type="recurrent",
    n_components=15,
    latent_dim=8,
    kl_warmup=10,
    kl_annealing_mode="linear",
    batch_size=128,
    kmeans_loss=0.0,
    reg_cat_clusters=0.0,
)
# Out:
# 2023-01-09 11:17:38.327392: I tensorflow/core/profiler/lib/profiler_session.cc:99] Profiler session initializing.
# 2023-01-09 11:17:38.327407: I tensorflow/core/profiler/lib/profiler_session.cc:114] Profiler session started.
# 2023-01-09 11:17:38.327527: I tensorflow/core/profiler/lib/profiler_session.cc:126] Profiler session tear down.
# Epoch 1/10
# 2023-01-09 11:17:46.811979: W tensorflow/core/framework/dataset.cc:768] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# 195/195 [==============================] - 24s 36ms/step - total_loss: 4001.2876 - reconstruction_loss: 3999.5061 - clustering_loss: 0.0000e+00 - prior_loss: 0.0000e+00 - kl_weight: 0.0497 - kl_divergence: -5.2437 - kmeans_loss: 1.8970 - number_of_populated_clusters: 8.7385 - confidence_in_selected_cluster: 0.8271
# Epoch 2/10
# 195/195 [==============================] - 6s 30ms/step - total_loss: 2628.7861 - reconstruction_loss: 2627.7949 - clustering_loss: 0.0000e+00 - prior_loss: 0.0000e+00 - kl_weight: 0.1497 - kl_divergence: -4.6928 - kmeans_loss: 1.6648 - number_of_populated_clusters: 9.5538 - confidence_in_selected_cluster: 0.7533
# Epoch 3/10
# 195/195 [==============================] - 6s 30ms/step - total_loss: 1511.5493 - reconstruction_loss: 1511.1846 - clustering_loss: 0.0000e+00 - prior_loss: 0.0000e+00 - kl_weight: 0.2497 - kl_divergence: -4.6792 - kmeans_loss: 1.5070 - number_of_populated_clusters: 11.3231 - confidence_in_selected_cluster: 0.6177
# Epoch 4/10
#   5/195 [..............................] - ETA: 6s - total_loss: 1149.4695 - reconstruction_loss: 1149.3873 - clustering_loss: 0.0000e+00 - prior_loss: 0.0000e+00 - kl_weight: 0.3010 - kl_divergence: -4.7611 - kmeans_loss: 1.4826 - number_of_populated_clusters: 12.4000 - confidence_in_selected_cluster: 0.6005
# 2023-01-09 11:18:22.388343: W tensorflow/core/framework/dataset.cc:768] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# 195/195 [==============================] - 6s 30ms/step - total_loss: 794.3317 - reconstruction_loss: 794.5036 - clustering_loss: 0.0000e+00 - prior_loss: 0.0000e+00 - kl_weight: 0.3497 - kl_divergence: -4.8889 - kmeans_loss: 1.4930 - number_of_populated_clusters: 11.7795 - confidence_in_selected_cluster: 0.5938
# Epoch 5/10
# 195/195 [==============================] - 6s 30ms/step - total_loss: 464.0164 - reconstruction_loss: 464.8135 - clustering_loss: 0.0000e+00 - prior_loss: 0.0000e+00 - kl_weight: 0.4497 - kl_divergence: -5.3021 - kmeans_loss: 1.4878 - number_of_populated_clusters: 12.8769 - confidence_in_selected_cluster: 0.5500
# Epoch 6/10
# 195/195 [==============================] - 6s 30ms/step - total_loss: 363.3380 - reconstruction_loss: 364.7625 - clustering_loss: 0.0000e+00 - prior_loss: 0.0000e+00 - kl_weight: 0.5497 - kl_divergence: -5.8620 - kmeans_loss: 1.5879 - number_of_populated_clusters: 12.8000 - confidence_in_selected_cluster: 0.5811
# Epoch 7/10
# 195/195 [==============================] - 6s 30ms/step - total_loss: 344.2538 - reconstruction_loss: 346.5208 - clustering_loss: 0.0000e+00 - prior_loss: 0.0000e+00 - kl_weight: 0.6497 - kl_divergence: -6.8812 - kmeans_loss: 1.7344 - number_of_populated_clusters: 13.3282 - confidence_in_selected_cluster: 0.6035
# Epoch 8/10
# 195/195 [==============================] - 6s 30ms/step - total_loss: 341.8422 - reconstruction_loss: 345.1892 - clustering_loss: 0.0000e+00 - prior_loss: 0.0000e+00 - kl_weight: 0.7497 - kl_divergence: -8.2437 - kmeans_loss: 1.8916 - number_of_populated_clusters: 13.9385 - confidence_in_selected_cluster: 0.6110
# Epoch 9/10
# 195/195 [==============================] - 6s 29ms/step - total_loss: 340.6454 - reconstruction_loss: 345.0990 - clustering_loss: 0.0000e+00 - prior_loss: 0.0000e+00 - kl_weight: 0.8497 - kl_divergence: -9.4525 - kmeans_loss: 2.0843 - number_of_populated_clusters: 13.8513 - confidence_in_selected_cluster: 0.6504
# Epoch 10/10
#   5/195 [..............................] - ETA: 6s - total_loss: 325.6193 - reconstruction_loss: 330.6022 - clustering_loss: 0.0000e+00 - prior_loss: 0.0000e+00 - kl_weight: 0.9010 - kl_divergence: -10.2578 - kmeans_loss: 2.2980 - number_of_populated_clusters: 13.6000 - confidence_in_selected_cluster: 0.7003
# 2023-01-09 11:18:57.843926: W tensorflow/core/framework/dataset.cc:768] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# 195/195 [==============================] - 6s 30ms/step - total_loss: 340.3441 - reconstruction_loss: 345.9033 - clustering_loss: 0.0000e+00 - prior_loss: 0.0000e+00 - kl_weight: 0.9497 - kl_divergence: -10.4939 - kmeans_loss: 2.2975 - number_of_populated_clusters: 13.4872 - confidence_in_selected_cluster: 0.6937
# Epoch 1/15
#   1/195 [..............................] - ETA: 20:33 - total_loss: 252.9745 - reconstruction_loss: 246.6704 - clustering_loss: -0.9965 - prior_loss: 2.7080 - kl_weight: 0.0000e+00 - kl_divergence: -10.7225 - kmeans_loss: 2.3361 - number_of_populated_clusters: 7.0000 - confidence_in_selected_cluster: 0.9975
# 2023-01-09 11:19:11.355486: I tensorflow/core/profiler/lib/profiler_session.cc:99] Profiler session initializing.
# 2023-01-09 11:19:11.355502: I tensorflow/core/profiler/lib/profiler_session.cc:114] Profiler session started.
#   6/195 [..............................] - ETA: 3:09 - total_loss: 278.6825 - reconstruction_loss: 272.4191 - clustering_loss: -0.9992 - prior_loss: 2.7080 - kl_weight: 0.0013 - kl_divergence: -10.6918 - kmeans_loss: 2.3297 - number_of_populated_clusters: 6.8333 - confidence_in_selected_cluster: 0.9995
# 2023-01-09 11:19:16.230559: I tensorflow/core/profiler/lib/profiler_session.cc:66] Profiler session collecting data.
# 2023-01-09 11:19:16.234831: I tensorflow/core/profiler/lib/profiler_session.cc:126] Profiler session tear down.
# 2023-01-09 11:19:16.239722: I tensorflow/core/profiler/rpc/client/save_profile.cc:136] Creating directory: /Users/lucas_miranda/PycharmProjects/deepof/unsupervised_trained_models/fit/deepof_unsupervised_VaDE_recurrent_encodings_input_type=coords_kmeans_loss=0.0_encoding=8_k=15_20230109-111738/plugins/profile/2023_01_09_11_19_16
#
# 2023-01-09 11:19:16.241575: I tensorflow/core/profiler/rpc/client/save_profile.cc:142] Dumped gzipped tool data for trace.json.gz to /Users/lucas_miranda/PycharmProjects/deepof/unsupervised_trained_models/fit/deepof_unsupervised_VaDE_recurrent_encodings_input_type=coords_kmeans_loss=0.0_encoding=8_k=15_20230109-111738/plugins/profile/2023_01_09_11_19_16/MC-C9791E.local.trace.json.gz
# 2023-01-09 11:19:16.246778: I tensorflow/core/profiler/rpc/client/save_profile.cc:136] Creating directory: /Users/lucas_miranda/PycharmProjects/deepof/unsupervised_trained_models/fit/deepof_unsupervised_VaDE_recurrent_encodings_input_type=coords_kmeans_loss=0.0_encoding=8_k=15_20230109-111738/plugins/profile/2023_01_09_11_19_16
#
# 2023-01-09 11:19:16.246947: I tensorflow/core/profiler/rpc/client/save_profile.cc:142] Dumped gzipped tool data for memory_profile.json.gz to /Users/lucas_miranda/PycharmProjects/deepof/unsupervised_trained_models/fit/deepof_unsupervised_VaDE_recurrent_encodings_input_type=coords_kmeans_loss=0.0_encoding=8_k=15_20230109-111738/plugins/profile/2023_01_09_11_19_16/MC-C9791E.local.memory_profile.json.gz
# 2023-01-09 11:19:16.247918: I tensorflow/core/profiler/rpc/client/capture_profile.cc:251] Creating directory: /Users/lucas_miranda/PycharmProjects/deepof/unsupervised_trained_models/fit/deepof_unsupervised_VaDE_recurrent_encodings_input_type=coords_kmeans_loss=0.0_encoding=8_k=15_20230109-111738/plugins/profile/2023_01_09_11_19_16
# Dumped tool data for xplane.pb to /Users/lucas_miranda/PycharmProjects/deepof/unsupervised_trained_models/fit/deepof_unsupervised_VaDE_recurrent_encodings_input_type=coords_kmeans_loss=0.0_encoding=8_k=15_20230109-111738/plugins/profile/2023_01_09_11_19_16/MC-C9791E.local.xplane.pb
# Dumped tool data for overview_page.pb to /Users/lucas_miranda/PycharmProjects/deepof/unsupervised_trained_models/fit/deepof_unsupervised_VaDE_recurrent_encodings_input_type=coords_kmeans_loss=0.0_encoding=8_k=15_20230109-111738/plugins/profile/2023_01_09_11_19_16/MC-C9791E.local.overview_page.pb
# Dumped tool data for input_pipeline.pb to /Users/lucas_miranda/PycharmProjects/deepof/unsupervised_trained_models/fit/deepof_unsupervised_VaDE_recurrent_encodings_input_type=coords_kmeans_loss=0.0_encoding=8_k=15_20230109-111738/plugins/profile/2023_01_09_11_19_16/MC-C9791E.local.input_pipeline.pb
# Dumped tool data for tensorflow_stats.pb to /Users/lucas_miranda/PycharmProjects/deepof/unsupervised_trained_models/fit/deepof_unsupervised_VaDE_recurrent_encodings_input_type=coords_kmeans_loss=0.0_encoding=8_k=15_20230109-111738/plugins/profile/2023_01_09_11_19_16/MC-C9791E.local.tensorflow_stats.pb
# Dumped tool data for kernel_stats.pb to /Users/lucas_miranda/PycharmProjects/deepof/unsupervised_trained_models/fit/deepof_unsupervised_VaDE_recurrent_encodings_input_type=coords_kmeans_loss=0.0_encoding=8_k=15_20230109-111738/plugins/profile/2023_01_09_11_19_16/MC-C9791E.local.kernel_stats.pb
# 195/195 [==============================] - 17s 56ms/step - total_loss: 347.9042 - reconstruction_loss: 344.0919 - clustering_loss: -0.9995 - prior_loss: 2.7080 - kl_weight: 0.0497 - kl_divergence: -7.6952 - kmeans_loss: 1.6543 - number_of_populated_clusters: 6.5846 - confidence_in_selected_cluster: 0.9997 - lr: 0.0010
# Epoch 2/15
# 195/195 [==============================] - ETA: 0s - total_loss: 346.8431 - reconstruction_loss: 344.5383 - clustering_loss: -0.9995 - prior_loss: 2.7080 - kl_weight: 0.1497 - kl_divergence: -5.7461 - kmeans_loss: 1.2947 - number_of_populated_clusters: 6.5744 - confidence_in_selected_cluster: 0.9996
# 2023-01-09 11:19:28.130875: W tensorflow/core/framework/dataset.cc:768] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# 195/195 [==============================] - 6s 31ms/step - total_loss: 346.8431 - reconstruction_loss: 344.5383 - clustering_loss: -0.9995 - prior_loss: 2.7080 - kl_weight: 0.1497 - kl_divergence: -5.7461 - kmeans_loss: 1.2947 - number_of_populated_clusters: 6.5744 - confidence_in_selected_cluster: 0.9996 - lr: 0.0010
# Epoch 3/15
# 195/195 [==============================] - 6s 30ms/step - total_loss: 346.4044 - reconstruction_loss: 344.7278 - clustering_loss: -0.9995 - prior_loss: 2.7080 - kl_weight: 0.2497 - kl_divergence: -5.5103 - kmeans_loss: 1.2244 - number_of_populated_clusters: 6.7128 - confidence_in_selected_cluster: 0.9997 - lr: 0.0010
# Epoch 4/15
# 195/195 [==============================] - 6s 31ms/step - total_loss: 346.0732 - reconstruction_loss: 344.9660 - clustering_loss: -0.9995 - prior_loss: 2.7080 - kl_weight: 0.3497 - kl_divergence: -5.5645 - kmeans_loss: 1.2215 - number_of_populated_clusters: 6.4462 - confidence_in_selected_cluster: 0.9996 - lr: 0.0010
# Epoch 5/15
# 195/195 [==============================] - 6s 30ms/step - total_loss: 345.1260 - reconstruction_loss: 344.6343 - clustering_loss: -0.9998 - prior_loss: 2.7080 - kl_weight: 0.4497 - kl_divergence: -6.0317 - kmeans_loss: 1.2914 - number_of_populated_clusters: 5.9231 - confidence_in_selected_cluster: 0.9998 - lr: 0.0010
# Epoch 6/15
# 195/195 [==============================] - 6s 31ms/step - total_loss: 345.5611 - reconstruction_loss: 345.8026 - clustering_loss: -0.9998 - prior_loss: 2.7080 - kl_weight: 0.5497 - kl_divergence: -6.9956 - kmeans_loss: 1.4479 - number_of_populated_clusters: 5.2974 - confidence_in_selected_cluster: 0.9999 - lr: 0.0010
# Epoch 7/15
# 195/195 [==============================] - ETA: 0s - total_loss: 344.8642 - reconstruction_loss: 345.9156 - clustering_loss: -0.9999 - prior_loss: 2.7080 - kl_weight: 0.6497 - kl_divergence: -8.1257 - kmeans_loss: 1.6704 - number_of_populated_clusters: 4.1436 - confidence_in_selected_cluster: 0.9999
# 2023-01-09 11:19:58.521246: W tensorflow/core/framework/dataset.cc:768] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# 195/195 [==============================] - 6s 30ms/step - total_loss: 344.8642 - reconstruction_loss: 345.9156 - clustering_loss: -0.9999 - prior_loss: 2.7080 - kl_weight: 0.6497 - kl_divergence: -8.1257 - kmeans_loss: 1.6704 - number_of_populated_clusters: 4.1436 - confidence_in_selected_cluster: 0.9999 - lr: 0.0010
# Epoch 8/15
# 195/195 [==============================] - 6s 31ms/step - total_loss: 344.1566 - reconstruction_loss: 346.0891 - clustering_loss: -0.9998 - prior_loss: 2.7080 - kl_weight: 0.7497 - kl_divergence: -8.9314 - kmeans_loss: 1.8416 - number_of_populated_clusters: 4.0974 - confidence_in_selected_cluster: 0.9999 - lr: 0.0010
# Epoch 9/15
# 195/195 [==============================] - 6s 30ms/step - total_loss: 342.7903 - reconstruction_loss: 345.6693 - clustering_loss: -0.9998 - prior_loss: 2.7080 - kl_weight: 0.8497 - kl_divergence: -9.7527 - kmeans_loss: 2.0445 - number_of_populated_clusters: 4.3128 - confidence_in_selected_cluster: 0.9999 - lr: 0.0010
# Epoch 10/15
# 195/195 [==============================] - 6s 31ms/step - total_loss: 341.8097 - reconstruction_loss: 345.7133 - clustering_loss: -0.9999 - prior_loss: 2.7080 - kl_weight: 0.9497 - kl_divergence: -10.5096 - kmeans_loss: 2.2508 - number_of_populated_clusters: 3.7385 - confidence_in_selected_cluster: 0.9999 - lr: 0.0010
# Epoch 11/15
# 195/195 [==============================] - 6s 32ms/step - total_loss: 341.9073 - reconstruction_loss: 346.3556 - clustering_loss: -0.9999 - prior_loss: 2.7080 - kl_weight: 1.0000 - kl_divergence: -10.8982 - kmeans_loss: 2.3542 - number_of_populated_clusters: 4.0103 - confidence_in_selected_cluster: 0.9999 - lr: 0.0010
# Epoch 12/15
# 195/195 [==============================] - 6s 31ms/step - total_loss: 342.0043 - reconstruction_loss: 346.4582 - clustering_loss: -1.0000 - prior_loss: 2.7080 - kl_weight: 1.0000 - kl_divergence: -10.9725 - kmeans_loss: 2.3744 - number_of_populated_clusters: 4.1949 - confidence_in_selected_cluster: 1.0000 - lr: 0.0010
# 2023-01-09 11:20:29.224271: W tensorflow/core/framework/dataset.cc:768] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# Epoch 13/15
# 195/195 [==============================] - 6s 30ms/step - total_loss: 340.8651 - reconstruction_loss: 345.3200 - clustering_loss: -0.9999 - prior_loss: 2.7080 - kl_weight: 1.0000 - kl_divergence: -10.9337 - kmeans_loss: 2.3618 - number_of_populated_clusters: 4.0974 - confidence_in_selected_cluster: 0.9999 - lr: 0.0010
# Epoch 14/15
# 195/195 [==============================] - 6s 30ms/step - total_loss: 340.6079 - reconstruction_loss: 345.0449 - clustering_loss: -0.9999 - prior_loss: 2.7080 - kl_weight: 1.0000 - kl_divergence: -10.9359 - kmeans_loss: 2.3779 - number_of_populated_clusters: 4.0051 - confidence_in_selected_cluster: 0.9999 - lr: 0.0010
# Epoch 15/15
# 195/195 [==============================] - 6s 30ms/step - total_loss: 341.8650 - reconstruction_loss: 346.3181 - clustering_loss: -0.9999 - prior_loss: 2.7080 - kl_weight: 1.0000 - kl_divergence: -10.9953 - kmeans_loss: 2.3827 - number_of_populated_clusters: 3.8513 - confidence_in_selected_cluster: 1.0000 - lr: 0.0010
# CPU times: user 6min 28s, sys: 1min 16s, total: 7min 45s
# Wall time: 3min 10s

# %% [markdown]
# ### Understanding the different available models

# %% [markdown]
# ### Cluster number selection

# %% [markdown]
# ### Visualizing temporal and global embeddings

# %%
my_deepof_project.get_exp_conditions
# Out:
# {'20191204_Day2_SI_JB08_Test_56': 'Stressed',
#  '20191204_Day2_SI_JB08_Test_61': 'Stressed',
#  '20191204_Day2_SI_JB08_Test_62': 'Stressed',
#  '20191204_Day2_SI_JB08_Test_54': 'Nonstressed',
#  '20191204_Day2_SI_JB08_Test_63': 'Nonstressed',
#  '20191204_Day2_SI_JB08_Test_64': 'Nonstressed'}

# %%
embeddings = {}
soft_counts = {}

for key in my_deepof_project.get_exp_conditions.keys():
    
    print(key)
    
    dd, _, _ = my_deepof_project.get_graph_dataset(
        animal_id="B",
        precomputed_tab_dict=to_preprocess.filter_videos([key]),
        preprocess=True,
        scale="standard",
        shuffle=False,
    )

    dd = (dd[0], dd[1], dd[2], dd[3], dd[4], dd[5])

#     dd = my_deepof_project.get_coords(
#         center="Center", align="Spine_1"
#     ).filter_id("B").filter_videos([key]).preprocess(
#         shuffle=False,
#         test_videos=0,
#     )
#     dd = [dd[0], dd[0]]
    
    embeddings[key] = cons.encoder([dd[0][:, :, :22], dd[1]])
    soft_counts[key] = cons.grouper([dd[0][:, :, :22], dd[1]])
# Out:
# 20191204_Day2_SI_JB08_Test_56
# 20191204_Day2_SI_JB08_Test_61
# 20191204_Day2_SI_JB08_Test_62
# 20191204_Day2_SI_JB08_Test_54
# 20191204_Day2_SI_JB08_Test_63
# 20191204_Day2_SI_JB08_Test_64

# %%
# TEMPORARY SOLUTION: Load precomputed embeddings. 
# Solve this later by defaulting embedding saving to a known directory within the project path.

# import pickle

# emb="TCN"
# run=2
# with open(f"../../../Results/CSDS_embeddings/deepof_unsupervised_VaDE_encoder_{emb}_encodings_input=graph_k=25_latdim=8_changepoints_False_kmeans_loss=0.0_run={run}.pkl", "rb") as handle:
#     embeddings, soft_counts, breaks = pickle.load(handle)

# %%
def get_patched_breaks(key):
        
    tt, g, prep = my_deepof_project.get_graph_dataset(center="Center", align="Spine_1", animal_id="B", shuffle=False)
    tt = my_deepof_project.get_graph_dataset(
        precomputed_tab_dict=prep.filter_videos([key]),
        animal_id="B",
        window_size=25,
        window_step=1,
        shuffle=False,
        automatic_changepoints=False,
        scale="standard",
        test_videos=0,
    )[0]

    return (~np.all(tt[0] == 0, axis=2)).sum(axis=1)

# %%
import numpy as np
breaks = {
    key: get_patched_breaks(key) for key in my_deepof_project.get_exp_conditions.keys()
}

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))
sns.set_context("talk")

deepof.visuals.plot_embeddings(
    my_deepof_project, 
    embeddings, 
    soft_counts,
    breaks,
    aggregate_experiments=False,
    ax=ax1,
    save=False, # Set to True, or give a custom name, to save the plot
)

deepof.visuals.plot_embeddings(
    my_deepof_project,
    embeddings, 
    soft_counts,
    breaks,
    aggregate_experiments="mean",
    ax=ax2,
    save=False, # Set to True, or give a custom name, to save the plot,
)

plt.tight_layout()
plt.show()
# Out:
# /Users/lucas_miranda/PycharmProjects/deepof/deepof/visuals.py:503: UserWarning: The palette list has more values (13) than needed (9), which may not be intended.
#   sns.scatterplot(

# %%
from IPython import display

video = deepof.visuals.animate_skeleton(
    my_deepof_project,
    embedding=embeddings,
    cluster_assignments=soft_counts,
    experiment_id="20191204_Day2_SI_JB08_Test_54",
    frame_limit=250,
    # selected_cluster=11,
    dpi=60,
    #center="Center",
    #align="Spine_1",
    #embedding=[emb_B, emb_W],
)

html = display.HTML(video)
display.display(html)
plt.close()
# Out:
# <video width="960" height="480" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# ### Global separation dynamics

# %% [markdown]
# ### Exploring cluster enrichment across conditions

# %% [markdown]
# ### Exploring cluster dynamics across conditions

# %%
fig = plt.figure(figsize=(12, 6))
sns.set_context("talk")

deepof.visuals.plot_gantt(
    my_deepof_project,
    soft_counts=soft_counts,
    experiment_id="20191204_Day2_SI_JB08_Test_54",
)

# %% [markdown]
# ### Interpreting clusters using SHAP

# %% [markdown]
# ### Exporting cluster video snippets

# %%
# TODO: they should be saved to a directory that makes sense!.

# %%
import pandas as pd
import os

files = [i for i in os.listdir("../../Desktop/deepOF_datasets/Tagged_videos/Data_for_deepof_OF/JB08_files_OF/Tables/")]

for f in files:
    cur = pd.read_hdf("../../Desktop/deepOF_datasets/Tagged_videos/Data_for_deepof_OF/JB08_files_OF/Tables/" + f)
    
    cur.to_csv("../../Desktop/deepOF_datasets/Tagged_videos/Data_for_deepof_OF/JB08_files_OF/Tables/" + f[:-2] + "csv")

# %%
emb = cons.encoder([pp[0][:25000], pp[1][:25000]])
cls = cons.quantizer([pp[0][:25000], pp[1][:25000]])

# %%
import umap
umap = umap.UMAP(
    n_components=2, 
    n_neighbors=250,
    min_dist=1.0,
).fit_transform(emb.numpy())
# umap = emb.numpy()

# %%
from collections import Counter

Counter(cls.numpy().argmax(axis=1))

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#tt = GaussianMixture(n_components=5, covariance_type="diag", reg_covar=1e-04).fit(emb.numpy())
#means = tt.means_
#means = cons.get_gmm_params['means'].numpy()

sns.scatterplot(x=umap[:, 0], y=umap[:, 1], hue=cls.numpy().argmax(axis=1), palette="tab20")
# means = cons.get_layer("grouper").get_layer("gaussian_mixture_latent").c_mu.numpy()
# sns.scatterplot(x=means[:,0], y=means[:,1], s=250, c="black")

plt.title("DeepOF embeddings")

# plt.legend("")
plt.show()

# %%
cons.get_gmm_params['weights'].numpy().sum()

# %%
tt = np.split(np.concatenate(tt), np.cumsum([i.shape[0] for k,i in vqvae_solution[0].items() if k in list(cc.keys())]))

for i in tt:
    print(i.shape)
    print(np.max(np.abs(i.mean(axis=0))))
    print(np.mean(np.abs(i.std(axis=0))))

# %%
# import pickle
# import numpy as np
# with open("../train_models/deepof_unsupervised_VQVAE_encodings_input=coords_k=100_latdim=8_kmeans_loss=0.0_run=1.pkl", "rb") as handle:
#     vqvae_solution = pickle.load(handle)

# %%
# from sklearn.cluster import AgglomerativeClustering
# from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
# from deepof.post_hoc import get_transitions
# from hmmlearn.hmm import GaussianHMM
# from tqdm import tqdm_notebook as tqdm


# def merge_and_smooth_clusters(
#     n_clusters, centroids, embedding, concat_embedding, cluster_assignments
# ):
#     """Merges the current clusters using a hierarchical agglomerative approach, and smoothens using a Gaussian HMM.

#     Args:
#         n_clusters (int): number of clusters to report.
#         centroids (np.ndarray): precomputed means per cluster.
#         embedding (tabdict): original deepof.TableDict object containing unsupervised embeddings.
#         concat_embedding (np.ndarray): concatenated list of embeddings per animal in the dataset.
#         cluster_assignments (tabdict): original deepof.TableDict object containing cluster assignments.

#     Returns:
#         new_soft_assignments (np.ndarray): concatenated postprocessed assignments for all animals in the dataset.
#     """

#     # Merge clusters ussing a hierarchical agglomerative approach
#     new_hard_assignments = AgglomerativeClustering(
#         n_clusters=n_clusters, compute_distances=True
#     ).fit_predict(centroids)
#     cluster_predictor = LinearDiscriminantAnalysis().fit(
#         centroids, new_hard_assignments
#     )
#     centroids = cluster_predictor.means_
#     new_soft_assignments = cluster_predictor.predict_proba(concat_embedding)

#     # Rebuild the soft assignments dictionary per experimental animal
#     new_soft_assignments = np.split(
#         new_soft_assignments,
#         np.cumsum([i.shape[0] for i in embedding.values()]),
#     )
#     new_soft_assignments = {
#         key: val for key, val in zip(cluster_assignments.keys(), new_soft_assignments)
#     }

#     # Smooth assignments across time using a Gaussian HMM on the embeddings, with priors based on the clustering results
#     for key, val in tqdm(new_soft_assignments.items()):

#         hmm = GaussianHMM(
#             startprob_prior=np.unique(val.argmax(axis=1), return_counts=True)[1],
#             transmat_prior=get_transitions(val.argmax(axis=1), n_states=n_clusters) + 10,
#             means_prior=centroids,
#             n_components=n_clusters,
#             covariance_type="diag",
#             n_iter=100,
#             tol=0.0001,
#         )
        
#         hmm.fit(embedding[key].numpy())
#         new_soft_assignments[key] = hmm.predict_proba(embedding[key].numpy())

#     return new_soft_assignments


# def cluster_postprocessing(embedding, cluster_assignments, n_clusters="auto"):
#     """Merges clusters using a hierarchical approach.

#     Args:
#         embedding (list): list of embeddings per animal in the dataset.
#         cluster_assignments (list): list of cluster assignments per animal in the dataset.
#         n_clusters (int): number of clusters to report.

#     Returns:
#         new_soft_assignments (list): list of new (merged) cluster assignments.

#     """
#     # Concatenate embeddings and cluster assignments in to unique np.ndarray objects
#     concat_embedding = np.concatenate([tensor.numpy() for tensor in embedding.values()])
#     hard_assignments = np.concatenate(
#         [tensor.numpy().argmax(axis=1) for tensor in cluster_assignments.values()]
#     )

#     assert concat_embedding.shape[0] == hard_assignments.shape[0]

#     # Get cluster centroids from the concatenated embeddings
#     centroids = []
#     for cluster in range(np.max(hard_assignments)):
#         centroid = concat_embedding[hard_assignments == cluster]
#         if len(centroid) == 0:
#             continue
#         centroid = np.mean(centroid, axis=0)
#         centroids.append(centroid)

#     centroids = np.stack(centroids)

#     # Merge centroids using a hierarchical approach with the given resolution, and soft-assign instances to clusters
#     if isinstance(n_clusters, int):
#         new_soft_assignments = merge_and_smooth_clusters(
#             n_clusters, centroids, embedding, concat_embedding, cluster_assignments
#         )

#     else:
#         raise NotImplementedError

#     return new_soft_assignments

# %%
# from hmmlearn.hmm import GaussianHMM

# new_ass = cluster_postprocessing(
#     vqvae_solution[0], 
#     vqvae_solution[1],
#     n_clusters=12
# )
# hcc = new_ass['20191203_Day1_SI_JB08_Test_54'].argmax(axis=1)

# %%
# import umap

# # Cluster on the original embedding space
# new_emb = umap.UMAP(n_components=2, n_neighbors=75).fit_transform(vqvae_solution[0]['20191203_Day1_SI_JB08_Test_54'])

# sns.scatterplot(x=new_emb[:, 0], y=new_emb[:, 1], hue=hcc, palette="tab20")

# plt.show()

# %%
# # How prevalent are these clusters?
# from collections import Counter
# print(Counter(hcc))

# new_ass = hcc

# %%
# # How often does the model change clusters?
# from collections import defaultdict

# lengths = defaultdict(list)
# cur = 0
# for i in range(1, len(new_ass)):
#     if new_ass[i-1] == new_ass[i]:
#         cur += 1
#     else:
#         lengths[new_ass[i-1]].append(cur)
#         cur = 1

# {key:np.mean(val) for key, val in lengths.items()}

# %%
# import pandas as pd

# # Duration histograms per cluster
# lengths_df = pd.DataFrame([lengths]).melt().explode("value").astype(int)
# sns.violinplot(data=lengths_df, x="variable", y="value")

# plt.axhline(25, linestyle="--", color="black")
        
# plt.show()
